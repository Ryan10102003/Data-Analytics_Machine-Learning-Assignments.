# %% [markdown]
# # EDA 1
# #Title: Bike Details Dataset
# Questions And Answers
#
# 1. What is the range of selling prices in the dataset?
#  - The range of selling prices is from ₹5,000 to ₹7,60,000.
#
# 2. What is the median selling price for bikes in the dataset?
#  - The median selling price for bikes in the dataset is ₹45,000.
#
# 3. What is the most common seller type?
#  - The most common seller type is Individual.
#
# 4. How many bikes have driven more than 50,000 kilometers?
#  - 215 bikes have driven more than 50,000 kilometers.
#
# 5. What is the average km_driven value for each ownership type?
#  - * 1st owner: 28,538 km
# * 2nd owner: 42,308 km
# * 3rd owner: 59,197 km
# * 4th & Above owner: 67,000 km
#
# 6. What proportion of bikes are from the year 2015 or older?
#  - Approximately 49.8% of the bikes are from the year 2015 or older.
#
# 7. What is the trend of missing values across the dataset?
#  - Only the ex\_showroom\_price column has missing values, with 435 entries missing out of 1061.
#
# 8. What is the highest ex_showroom_price recorded, and for which bike?
#  - Missing values: ex_showroom_price has 435 missing entries
#
# 9. What is the total number of bikes listed by each seller type?
#  - Bikes listed by seller type:
#    Individual: 1055 , Dealer: 6
#
# 10. What is the relationship between selling_price and km_driven for first-owner bikes?
#  - First-owner price vs km_driven: Slight negative trend (more driven → slightly lower price)
#
# 11. Identify and remove outliers in the km_driven column using the IQR method?
#  - Outliers in km_driven (IQR method): 44 rows removed
#
# 12. Perform a bivariate analysis to visualize the relationship between year and selling_price?
#  - Bivariate analysis (year vs price): Older bikes generally have lower prices
#
# 13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?
#  - Average depreciation/year: Approx ₹6161
#
# 14. Which bike names are priced significantly above the average price for their manufacturing year?
#  - Bikes priced above average for their year: Some Harley Davidson and Royal Enfield models
#
# 15.  Develop a correlation matrix for numeric columns and visualize it using a heatmap?
#  - Correlation heatmap created (selling_price strongly correlates with ex_showroom_price)
#
#
#  ----- END OF EDA 1 ----

# %% [markdown]
# # EDA 2
# #Title: Car Sale Dataset
#
# #Questions and Answers
#
#
# 1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?
#  - The average selling price of cars varies across dealers; top dealers by average price include "AutoMart", "CarZone", etc.
#
# 2.  Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trendsE?
#  - The company with the highest variation in prices is "Mercedes-Benz", indicating a wide range of models and price points.
#
# 3. The company with the highest variation in prices is "Mercedes-Benz", indicating a wide range of models and price points?
#  - Automatic cars generally have a higher median price than manual ones, with a wider interquartile range.
#
# 4. What is the distribution of car prices across different regions?
#  - Car prices vary by region, with the "West" and "South" regions having higher median prices.
#
# 5.  What is the distribution of cars based on body styles?
#  - SUVs are the most common body style, followed by Sedans and Hatchbacks
#
# 6. How does the average selling price of cars vary by customer gender and annual income?
#  - Males tend to purchase cars with higher average prices and have slightly higher average income
#
# 7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?
#  - The "West" region sells the most cars and also has the highest price distribution range.
#
# 8.  How does the average car price differ between cars with different engine sizes?
#  - Cars with "V8" and "V6" engines have the highest average prices
#
# 9. How do car prices vary based on the customer’s annual income bracket?
#  - Customers earning >1M annually buy the most expensive cars; prices increase with income brackets
#
# 10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?
#  - The top 5 models by sales include "Civic", "Corolla", "Camry", "Accord", and "Elantra" with varied price distributions.
#
#
# 11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?
#  - Red "V8" cars show the highest price variation across engine and color combinations.
#
# 12. Is there any seasonal trend in car sales based on the date of sale?
#  - Car sales peak in March and July, indicating potential seasonal trends.
#
# 13. How does the car price distribution change when considering different combinations of body style and transmission type?
#  - SUVs with automatic transmission tend to be the most expensive combination.
#
# 14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?
#  - Car price is moderately correlated with income (0.27) and engine size (0.19)
#
# 15.  How does the average car price vary across different car models and engine types?
#  - The "C-Class V6", "Mustang V8", and "X5 V8" models have the highest average prices.
#
#
#  ------ END OF EDA 2 ------

# %% [markdown]
# #EDA 3
# #Title: Amazon Sales Data
#
# #Questions and Answers
#
# 1. What is the average rating for each product category?
#  - Average rating by category: OfficeProducts (4.31), Toys&Games (4.3), HomeImprovement (4.25), Computers&Accessories (4.15), Electronics (4.08)
#
# 2.  What are the top rating_count products by category?
#  - Top rating_count products by category:
#  Electronics: AmazonBasics HDMI Cable (426,973 ratings)
# Home&Kitchen: Pigeon Handy Chopper (270,563)
# Computers&Accessories: SanDisk Cruzer Blade (253,105)
#
# 3. What is the distribution of discounted prices vs. actual prices?
#  - Price distribution: Mean actual price ₹5445, mean discounted price ₹3125, max actual price ₹139900, min ₹39
#
# 4. How does the average discount percentage vary across categories?
#  - Avg discount % by category: HomeImprovement (57.5%), Computers&Accessories (54%), Health&PersonalCare (53%), Electronics (50.8%)
#
# 5.  What are the most popular product names?
#  - Most popular product names: Fire-Boltt Ninja, Fire-Boltt Phoenix, Wayona Cable, MI Braided Cable, Amazonbasics Lightning Cable
#
# 6. What are the most popular product keywords?
#  - Popular keywords: "with", "your", "cable", "this", "from"
#
# 7. ' What are the most popular product reviews?
#  - Popular review titles: "Good", "Good product", "Value for money", "Nice", "Nice product"
#
# 8.  What is the correlation between discounted_price and rating?
#  - Correlation between discounted_price and rating: 0.12 (weak positive)
#
# 9.  What are the Top 5 categories based on the highest rating?
#  - Top 5 categories by rating: OfficeProducts, Toys&Games, HomeImprovement, Computers&Accessories, Electronics
#
# 10. Identify any potential areas for improvement or optimization based on the data analysis?
#  - Optimization area: Products with low ratings (<3.5) and high prices (>₹500), e.g., Skywall Smart TV, Firestick Remote, Canon Printer, etc.
#
#
# --------- END OF EDA 3-----
